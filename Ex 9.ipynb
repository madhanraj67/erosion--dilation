# %% [markdown]
# ## Exp-9- Record-IMPLEMENTATION OF EROSION AND DILATION
# ## NAME:MADHANRAJ P
# ## REG NO:212223220052

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = np.zeros((100, 600, 3), dtype='uint8')  # Black background (RGB: 0, 0, 0)
font = cv2.FONT_HERSHEY_COMPLEX
text_color = (255, 255, 255)  # White text (RGB: 255, 255, 255)
cv2.putText(img, 'MADHANRAJ', (60, 70), font, 2, text_color, 5, cv2.LINE_AA)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img_erode = cv2.erode(img,kernel1)
plt.imshow(img_erode)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(99.5), np.float64(-0.5))

# %%
img_dilate = cv2.dilate(img,kernel1)
plt.imshow(img_dilate)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(99.5), np.float64(-0.5))
